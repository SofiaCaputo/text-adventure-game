# %%
"""
    This game takes inspiration from some of the best scenes of the movie ‘Escape room’ (2019).
    An escape room is a room where people have some tools or clues to move to the next room/level before the time given runs out.
    In this movie it’s not just about time, it’s about living or dying and every room is made in a different context with various conditions. 
    Everything starts when an invitation is send to you to go play in one of the best escape room in the country.
    The game develops in 4 rooms, and if you make it to the end, you will be able to meet the Gamemaster.
    1st room: waiting room 
    2nd room: oven room  
    3rd room: upside room 
    4th room: hospital room

    Sometimes your choice won’t make you dye, some other, it will be the end for you, good luck!

    
    https://www.youtube.com/watch?v=KyJZgVFdJPU
    
"""
#importing libraries
from sys import exit
import random
import time

#def global fail function
def fail():
    print("You are dead ☠️, thanks for trying!")
    input(prompt='-Press any key to exit-\n')
def room_1():
#the rooms does not mean actually room of the game

#use the dynamic input function 
    name=input(prompt=f"""
Hi player, 
What is your name?\n\n""").capitalize()#use capitalize to show later the name with capital letter
    
#print the intro sentence by using a dynamic string to incorporate the name 
    print(f"""
'Hello {name}, 
 Minos Escape room is inviting you to join the game and if you win you get $10000' 💰\n""")


    answer = input(prompt = "Do you accept the invitation? (Yes/No)\n\n").casefold()

    if answer == 'yes' or answer == 'y':
        room_2() #this is the right answer that will take you to the next room
    
    else:
        print("I can't accept this answer! Let's try again")
        room_1() #this is not correct, that's why it will go back to the question

#create another room to actually start the game
def room_2():
       
    print("""
                    ЩΞLCФMΞ ΓФ ΓHΞ MIИФS ΞSCДPΞ ЯФФM
          """)
    
#enter button to start the game
    input(prompt = "click enter whenever you feel ready\n")
    
#give an introduction to understand the context
    print(""" 
You just walked into the waiting room but as soon as you close the door
you realize the doorknob breaks off into your hand and a code shows up.
You better start searching for clues.
          """)

#after this it will connect to the first real scene
    room_3()
    
#define another room to make it easier in case the question need to be ask again
def room_3():

#create a list
    code = ["I","know","every","move","you","are","making"] 
    
#use the random package to shuffle the sentence contained in the list 
    sequence = random.shuffle(code) 

    print(f"""To move forward, you need to type the correct sequence of the following sentence:\n """)
    print(code)
#set the player answer             
    sequence_guess = input(prompt="\n ").casefold() 
#conditional statatement     
  
    if sequence_guess == 'i know every move you are making':
        print("\nThat's the way to start!\n") 
        room_4()
        
    else:
        print("\nNot exactly, maybe some typing error.\n")
        room_3() #infinite trials
        
def room_4():
    print("""
                   🔥 W̾e̾l̾c̾o̾m̾e̾ ̾t̾o̾ ̾t̾h̾e̾ ̾O̾v̾e̾n̾ ̾R̾o̾o̾m̾ 🔥
          """)
    time.sleep(1.2) #create suspense 
    
#instructions about what is happening
    print("""
Now is a oven deal, the panel of the room turn on and is getting hotter and hotter🌡️, 
There are 3 options in front of you:\n""")
    time.sleep(0.8)
    room_5()
    
# create another room to make it easier to come back  
def room_5():
    
#create a list with the 3 options
    inventory = ['water', 'bottle', 'extinguisher']
#print the list to show it to the player
    for element in inventory:
        print(element)
        
#random package so every time is a different answer 
    hot= random.choice(inventory) 
    guesses= 2 #number of possible choice before loosing the game
#while loop   
    while guesses > 0:
        answer_1 = input(prompt = """
Which one would you pick?\n\n""").casefold()
        if answer_1 == hot:
            print("\nExcellent, let's move on!")
            room_6()
            break #correct answer bring you to the next room and interrupt the loop
            
        elif answer_1 != hot:
            guesses -=1 
                
            if guesses > 0:
                print(f"""\nIs getting hotter 🥵. You have {guesses} guesses left before burning.\n""")
                
            elif guesses == 0:
                print("\nToo hot to survive.\n")#if you don't have any guesses left, you loose
                fail()
        
            else:
                print("\nNot a possible answer\n")
                room_5() #if not a proper answer, it goes back again to the question
            
        else:
            print("\nThere something wrong\n")
             #if an aswer not expected, back to the question


        
def room_6():
#create another room to get to the actual 3rd room
    print("""
                    ɯooᴚ uʍop ǝpısd∩ ǝɥʇ oʇ ǝɯoɔlǝM
          """)
    time.sleep(0.8) #to give the time to the player to read step by step
    
    #make a question to start the while loop
    print("""
The next room is upside down and there is a phone ringing 📞 which tells you to guess the number
to unlock the safe. 
Be careful and watch your steps because the floor is slowly falling away!!
    """)
    print("""
'Guess we don't like PIN CODE', but you better give a trial. 
Pick a number from 1 to 11, you have time to make just 8 guesses\n""")
    
    room_7() #to take you to the next room
    
#define another room in order to not go all the way back in case of wrong answer    
def room_7():
    import random #import random to have a random output
    number= random.randint(1,11) #define number to be a random number between 1 and 11
    guesses= 8 #number of possible choice before loosing the game
#while loop   
    while guesses > 0:
        try:
            choice = int(input(prompt=">"))
        
            if choice == number:
                print("\n Is this your lucky number? Because it's right!")
                room_8()
                break #correct answer bring you to the next room and interrupt the loop
            
            elif choice != number:
                guesses-=1 #wrong choice, you have -1 guesses
           
                if guesses > 0:
                    print(f"\nStill locked 🔐. Just {guesses} guesses left.\n")
                
                elif guesses == 0:
                    print(f"\nYou run out of time. Game over.\n")#if you don't have any guesses left, you loose
                    input(prompt = "press enter to play again\n")
                    room_1()#if you want to play again, bring it back to the beginning
        
                else:
                    print("\nNot a possible answer\n")
                    room_7() #if not a proper answer, it goes back again to the question
            
        except ValueError:
                print("\nThere something wrong\n")
                pass #if an aswer not expected, back to the question
#define another room
def room_8():
    print("""
                   🏥 🅆🄴🄻🄲🄾🄼🄴 🅃🄾 🅃🄷🄴 🄷🄾🅂🄿🄸🅃🄰🄻 🅁🄾🄾🄼 🏥
          """)
#instructions for the room
    print("""
In the fourth room there are six hospital cubicles and it is made up to see who would ultimately survive. 
5 minutes countdown starts and a TV screen 🖥️ turns on showing a video of an open heart surgery 🫀 and it 
says that you need to put the heart into it.\n""")
    time.sleep(0.9)
#question
    print("""Do you have the heart to let Doctor Wootan Yu help you? 🩺""")
#create a list for the possible answers
   
    decision = ['stand', 'scream', 'walk']
    
#use random to change answer everytime
    heart= random.choice(decision) 
    guesses= 2 #number of possible choice before loosing the game
#while loop   
    while guesses > 0:
        answer_2= input(prompt="""You decide to: 
                                - stand
                                - scream
                                - walk \n\n""").casefold()
        if answer_2 in heart:
            print("\nThat is right!")
            room_9()
            break #correct answer bring you to the next room and interrupt the loop
            
        elif answer_2 not in heart:
            guesses -=1
            
            if guesses > 0:
                print(f"\nNot exactly, you are left with {guesses} guesses.\n")
                
            elif guesses == 0:
                print(f"\nI am sorry, you pick the wrong one.\n")#if you don't have any guesses left, you loose
                fail()
        
            else:
                print("\nNot a possible answer\n")
                room_8() #if not a proper answer, it goes back again to the question
            
        else:
            print("\nThere something wrong\n")
            room_8()
        
#define the next room
def room_9():
#same reasoning of the previous part, answer as input with conditional statement
    answer_3=input(prompt="""Why would you do this?
                                1) to destroy everything ⛏️
                                2) to find something 🔍\n\n""").casefold()
        
    if '1' in answer_3 or 'destroy everything' in answer_3 or 'destroy' in answer_3 or 'first' in answer_3:
        print("\nThat's not a good idea")
        room_9() #wrong answer, but possibility to answer again
            
    elif '2' in answer_3 or 'find something' in answer_3 or 'find' in answer_3 or 'second' in answer_3: 
        print("\nGood job! You find a clue, the x-ray is telling you something in sign language: EKG")
        room_10() #right answer, move on
    else:
        print("\nNot a valid answer. Insert another one")
        room_9() #unexpected answer, back to the question
        
#give some more instructions using the print function 
def room_10():
    print("""
Time is running and once the countdown will be over ⏱️, you will get poisoned. 
Remember that you just found an hint and is telling you to use the EKG machine.

To open the door there should be a certain level of heart rate 
(hint: below or above 50?)
         """)
#defining the answer as an input
    print("""
Guess the heart rate,
How much should it be?\n\n""")
    
    number= random.randint(1,50) #define number to be a random number between 1 and 50
    guesses= 30 #number of possible choice before loosing the game
#do a while loop   
    while guesses > 0:
        try:
            choice = int(input(prompt=">"))
        
            if choice <= 50:
                print(f"""\nYou are safe! Precisely the exact rate is {number}.""")
                room_12()
                break #correct answer bring you to the next room and interrupt the loop
            
            elif choice > 50:
                guesses-=1 #wrong choice, you have -1 guesses
           
                if guesses > 0:
                    print(f"\nThat's too high! Just {guesses} guesses left.\n")
                
                elif guesses == 0:
                    print(f"\nYou run out of time. Game over.\n")#if you don't have any guesses left, you loose
                    input(prompt = "press enter to play again\n")
                    room_1()#if you want to play again, bring it back to the beginning
        
                else:
                    print("\nNot a possible answer\n")
                    room_7() #if not a proper answer, it goes back again to the question
            
        except ValueError:
                print("\nThere something wrong\n")
                pass 

#define another scenario        
def room_12():
    print("""
The walls crush and you get into a large room full of screens and computers, 
you now understand it is the:

                    𝔊𝔞𝔪𝔢𝔪𝔞𝔰𝔱𝔢𝔯 ℜ𝔬𝔬𝔪""")
    
#conversation taken from the movie
    print("""
'You are the long shot'
'Does this means that I can leave because I won the game?'\n""") 
    question_4=input(prompt="If you were the Gamemaster would you answer 'yes' or 'no'? \n\n").casefold()
#define the answer    
    answer_6 = 'no' 
    
#check if question and answer correspond
    if question_4 == answer_6:
        print('\nYou are right, this is because you still have to kill the Gamemaster')
        room_13() #right answer, go to last room
        
#actually no need of elif because whatever is not a no is incorrect
    elif question_4 == 'yes' or question_4 == 'Yes' or question_4 == 'YES':
        print("\nAfter said so the Gamemaster will strangle you")
        fail()#wrong answer 
    else:
        print("\nSomething not correct, please try again")
        room_12() 
        
#define the last room        
def room_13():
#input question   
    question_5=input(prompt=
"""Would you rather:
                    1)smash his head with a glass container ⚗️
                    2)shoot him 🔫
Pick 1 or 2\n\n""").casefold()
#conditional statement
    if question_5 == '1' or 'smash his head' in question_5 or 'smash' in question_5:
        print(f"""
🏁 𝕮𝖔𝖓𝖌𝖗𝖆𝖙𝖚𝖑𝖆𝖙𝖎𝖔𝖓𝖘, 𝖞𝖔𝖚 𝖜𝖔𝖓! 🏁""")
        time.sleep(0.5) #right answer, you won
        
    elif question_5 == '2' or 'shoot him' in question_5 or 'shoot' in question_5:
        print("\nHe manages to run behind some crates and kill you..")
        fail() #wrong answer
    else:
        print("\nPlease insert either 1 or 2")
        room_13()
        #if some error in the answer occur, goes back to the question
     
    
    
    
room_1() #call first room to start the game
# Out:
# Hi player,
# What is your name?
#
# sofi
#
# 'Hello Sofi,
#  Minos Escape room is inviting you to join the game and if you win you get $10000' 💰
#
# Do you accept the invitation? (Yes/No)
#
# y
#
#                     ЩΞLCФMΞ ΓФ ΓHΞ MIИФS ΞSCДPΞ ЯФФM
#
# click enter whenever you feel ready
#
#
# You just walked into the waiting room but as soon as you close the door
# you realize the doorknob breaks off into your hand and a code shows up.
# You better start searching for clues.
#
# To move forward, you need to type the correct sequence of the following sentence:
#
# ['move', 'know', 'every', 'making', 'I', 'are', 'you']
#
#  I know every move you are making
#
# That's the way to start!
#
#
#                    🔥 W̾e̾l̾c̾o̾m̾e̾ ̾t̾o̾ ̾t̾h̾e̾ ̾O̾v̾e̾n̾ ̾R̾o̾o̾m̾ 🔥
#
#
# Now is a oven deal, the panel of the room turn on and is getting hotter and hotter🌡️,
# There are 3 options in front of you:
#
# water
# bottle
# extinguisher
#
# Which one would you pick?
#
# water
#
# ...
